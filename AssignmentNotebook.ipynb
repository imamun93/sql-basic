# %%
import pandas as pd
import psycopg2
import sqlalchemy
from sqlalchemy import create_engine 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import import_ipynb
from user_info import *

# %%
# %run user_info.ipynb

# %%
user_info
# Out:
# <module 'user_info' (<import_ipynb.NotebookLoader object at 0x117cd4048>)>

# %%
# Postgres username, password, and database name 
POSTGRES_ADDRESS = 'njoy-testing-env.c2ag7j9q24ns.us-east-1.rds.amazonaws.com'
POSTGRES_PORT = '5416' 
POSTGRES_USERNAME = username 
POSTGRES_PASSWORD = password 
POSTGRES_DBNAME = 'dev'

# %%
postgres_str = ('postgresql://{username}:{password}@{ipaddress}:{port}/{dbname}'
                .format(username=POSTGRES_USERNAME, 
                        password=POSTGRES_PASSWORD, 
                        ipaddress=POSTGRES_ADDRESS, 
                        port=POSTGRES_PORT, dbname=POSTGRES_DBNAME))

# %%
# Creating the engine
engine = create_engine(postgres_str)

# %%
engine
# Out:
# Engine(postgresql://reader:***@njoy-testing-env.c2ag7j9q24ns.us-east-1.rds.amazonaws.com:5416/dev)

# %%
pd.read_sql_query('''select count(1) from public.orders;''', engine)
# Out:
#     count
# 0  201570

# %%
pd.read_sql_query('''SELECT * FROM public.orders;''', engine)
# Out:
#             order_id customer_id          created_at          updated_at  \
# 0       8.974965e+11    230824c2 2019-03-13 18:14:55 2019-03-13 22:01:40
# 1       8.975937e+11    7100545b 2019-03-13 19:33:50 2019-03-13 23:01:21
# 2       8.975785e+11    3de1dc29 2019-03-13 19:20:05 2019-03-13 23:01:33
# 3       8.976117e+11    cb5e4189 2019-03-13 19:50:09 2019-03-13 23:01:12
# 4       8.976406e+11    579c3141 2019-03-13 20:17:01 2019-03-14 00:01:23
# 5       8.976555e+11    0de56532 2019-03-13 20:30:26 2019-03-14 00:01:11
# 6       8.976295e+11    d33c41ec 2019-03-13 20:05:57 2019-03-14 00:01:28
# 7       8.977876e+11    440115b9 2019-03-13 22:41:05 2019-03-14 14:06:51
# 8       8.870819e+11    a83fe907 2019-03-05 13:37:08 2019-03-14 16:27:18
# 9       8.980735e+11    d07fbbe1 2019-03-14 04:57:44 2019-03-14 16:05:27
# 10      8.983274e+11    327fd02a 2019-03-14 11:19:41 2019-03-14 16:03:44
# 11      8.983361e+11    422c851c 2019-03-14 11:29:42 2019-03-14 16:03:29
# ...
